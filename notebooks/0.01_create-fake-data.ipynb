# %%
import pandas as pd 
import numpy as np

# %%
inputs = pd.read_csv("../data/processed/ntof/ntof_inputs_eV.csv")

# %%
inputs['Gg(E=6keV)'] = inputs['Gg0']**2 / 3

# %%
inputs.to_csv("../data/processed/ntof/ntof_inputs_fake.csv", index=False)
